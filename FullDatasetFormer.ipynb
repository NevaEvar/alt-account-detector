# %%
import csv

#Creates the file where rawText will be processed into
with open('CleanText.csv', 'w', newline='', encoding='utf-8') as writeFile:
    writer = csv.writer(writeFile) 
    #Header
    writer.writerow(['User', 'Message'])

# %%
import import_ipynb
import RawTextCleaner
import AnalyzeAndReshape

pathList = [
    'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 1].txt',
    'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 2].txt',
    'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 3].txt',
    'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 4].txt', 
    'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 5].txt', 
    'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 6].txt'
]
    #'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 2].txt',
    #'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 3].txt'
    #'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 4].txt', 
    #'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 5].txt', 
    #'v1/content/drive/Shareddrives/Datasets/cleaned-v4/discord-v1-detox-antispam/[136542963336478720] [part 6].txt'


cleanFile = 'CleanText.csv'
finalFile = 'TrainingData.csv'

minMessages = 100
maxMessages = 10000
messagesPerColumn = 30 # has to be < minMessages / 3

#adds every convo from pathList to given csv file
for path in pathList:
    RawTextCleaner.RawTextToCSV(path)
print('Raw text parsing done.')

#takes readPath (CleanText.csv), minMessages and maxMessages then returns data and keepList of users who have desired range or messages
data, keepList = AnalyzeAndReshape.MessageFilter(cleanFile, minMessages, maxMessages)
print('Filtering by min and max messages done.')

#writes the final csv file that can be used to train the model
AnalyzeAndReshape.TrainingDataBuilder(data, keepList, finalFile, messagesPerColumn)
print('Final dataset done.')
# Out:
# Raw text parsing done.
# Filtering by min and max messages done.
# Processing users: 100%|██████████████████████████████████████████████████████████████| 519/519 [30:29<00:00,  3.53s/it]
# Final dataset done.
